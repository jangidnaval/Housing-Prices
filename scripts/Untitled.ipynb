# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fd=pd.read_csv('Bob.txt',header=None )
fd.head(n=20)
# Out:
#                                                     0
# 0                                House ID :  6e32cec0
# 1   Date Built : 4/21/1602 12:41 AM and Date Price...
# 2                        There is no space for garden
# 3    Distance from the Dock is 138.600639 holy lights
# 4       Distance from Capital is 0.256239 holy lights
# 5   Distance from Royal Market is 69.486467 holy l...
# 6   Distance from Guarding Tower is 14.394903 holy...
# 7    Distance from the River is 63.109038 holy lights
# 8                The house did not undergo renovation
# 9                            There are 3 dining rooms
# 10                               There are 4 bedrooms
# 11           King couldn't pay his visit to the house
# 12                 Sorcerer couldn't curse this house
# 13          King blessed the house with 160 blessings
# 14         There is a small land of farm in the front
# 15          Location of the house is : King's Landing
# ...

# %%
fd[0][1200]
# Out:
# "King couldn't pay his visit to the house"

# %%
fd.head(n=40)
# Out:
#                                                     0
# 0                                House ID :  6e32cec0
# 1   Date Built : 4/21/1602 12:41 AM and Date Price...
# 2                        There is no space for garden
# 3    Distance from the Dock is 138.600639 holy lights
# 4       Distance from Capital is 0.256239 holy lights
# 5   Distance from Royal Market is 69.486467 holy l...
# 6   Distance from Guarding Tower is 14.394903 holy...
# 7    Distance from the River is 63.109038 holy lights
# 8                The house did not undergo renovation
# 9                            There are 3 dining rooms
# 10                               There are 4 bedrooms
# 11           King couldn't pay his visit to the house
# 12                 Sorcerer couldn't curse this house
# 13          King blessed the house with 160 blessings
# 14         There is a small land of farm in the front
# 15          Location of the house is : King's Landing
# ...

# %%
print(fd[0][1])
# Out:
# Date Built : 4/21/1602 12:41 AM and Date Priced :  7/9/1609 1:11 AM

# %%
print('hello')
# Out:
# hello

# %%
fd.size
new_arr.clear()
new_arr
# Out:
# []

# %%
count=0
pre=0
new_arr=[]
del new_arr[:]
for i in range (1,fd.size):
    if "House ID" in fd[0][i]:
        new_arr.append(fd[0][pre:i])
        count=count+1
        pre=i

print(count)
# Out:
# 1291

# %%
new_arr.
# Out:
# [0                                  House ID :  6e32cec0
# 1     Date Built : 4/21/1602 12:41 AM and Date Price...
# 2                          There is no space for garden
# 3      Distance from the Dock is 138.600639 holy lights
# 4         Distance from Capital is 0.256239 holy lights
# 5     Distance from Royal Market is 69.486467 holy l...
# 6     Distance from Guarding Tower is 14.394903 holy...
# 7      Distance from the River is 63.109038 holy lights
# 8                  The house did not undergo renovation
# 9                              There are 3 dining rooms
# 10                                 There are 4 bedrooms
# 11             King couldn't pay his visit to the house
# 12                   Sorcerer couldn't curse this house
# 13            King blessed the house with 160 blessings
# 14           There is a small land of farm in the front
# 15            Location of the house is : King's Landing
# 16               Holy tree stands tall beside the house
# ...

# %%
arr
# Out:
# array([['House ID :  6e32cec0',
#         'Date Built : 4/21/1602 12:41 AM and Date Priced :  7/9/1609 1:11 AM',
#         'There is no space for garden', ...,
#         'There is a small land of farm in the front',
#         "Location of the house is : King's Landing",
#         'Holy tree stands tall beside the house'],
#        ["Distance from Knight's house is 10.505662 holy lights",
#         'House ID :  6e32ceda',
#         'Date Built : 10/23/1603 11:14 PM and Date Priced :  10/21/1611 7:40 AM',
#         ..., "Sorcerer couldn't curse this house",
#         'King blessed the house with 37 blessings',
#         'There is a huge land of farm in the front'],
#        ['Location of the house is : The Mountains',
#         'Holy tree stands tall beside the house',
#         "Distance from Knight's house is 132.934312 holy lights", ...,
#         'There are 3 bathrooms',
#         "King couldn't pay his visit to the house",
#         "Sorcerer couldn't curse this house"],
# ...

# %%
del new_arr[:]

# %%
print(new_arr)
# Out:
# []
